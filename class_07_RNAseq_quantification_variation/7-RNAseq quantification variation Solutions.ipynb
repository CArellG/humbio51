# %% [markdown]
# # Big Data for Biologists: Decoding Genomic Function- Class 7
#
# ## How do you quantify gene expression and visualize similarities and differences of gene expression profiles across cell types? Part I
#
# ##  Learning Objectives
# ***Students should be able to***
#  <ol>
#  <li> <a href=#GeneExpressionIntro>Quantify gene expression and understand units of gene expression levels</a></li>
#  <li> <a href=#GeneExpressionIntro>Understand what a box plot is</a></li>
#  <li> <a href=#GeneExpressionIntro>Visualize gene expression variation across cell types and individuals from the GTEx project</a></li>
#  <li><a href=#RNASeqDataFormat>Recognize that data from an RNA-Seq experiment can be processed and stored in a format that can be read into Python</a></li>
#  <li> <a href=#IDHeaderSep>Identify the separator and header in a data table</a></li>
#  <li><a href=#LoadTable> Load a data table in .csv or .tsv format into Python</a></li>
#  <li> <a href=#DataTableDim>Get the dimensions of a data table in Python  </a></li>
#  <li> <a href=#MetaData>Load RNA-Seq metadata for the physiological system of a cell type into Python</a></li>
#  <li> <a href=#Slicing>Slice a data table in Python to select a subset of rows or columns. </a></li>
#  <li> <a href=#Barplot>Make a bar plot from a data table using Python </a></li>
#  <li> <a href=#Transpose>Transpose a matrix using Python </a></li>
#  <li> <a href=#Merge>Merge two matrices using Python </a></li>
#  <li> <a href=#BinaryIndex>Use binary indexing to select elements from a dataframe. </a></li>

# %% [markdown]
# ## How do you quantify gene expression?

# %%
from IPython.display import HTML
HTML('<iframe src="https://docs.google.com/presentation/d/e/2PACX-1vRcZ3RiXYbwH_xrE-261ccJT71HKZ5oPJqmIATdHa2SwvDekvAR5Lr7zDwnNPN88FAEM2XT-F6-DHiS/embed?start=false&loop=false" frameborder="0" width="960" height="749" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>')
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vRcZ3RiXYbwH_xrE-261ccJT71HKZ5oPJqmIATdHa2SwvDekvAR5Lr7zDwnNPN88FAEM2XT-F6-DHiS/embed?start=false&loop=false" frameborder="0" width="960" height="749" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>

# %% [markdown]
# ## How does gene expression change across cell types and individuals?

# %% [markdown]
# Gene expression varies not only across cell types and tissues but also between healthy individuals and between health and diseased individuals.
#
# The aim of the Genotype - Tissue Expression (GTEx) Project is to increase our understanding of how changes in our genes contribute to common human diseases, in order to improve health care for future generations.
#
# Launched by the National Institutes of Health (NIH) in September 2010 (See: NIH launches Genotype-Tissue Expression project), GTEx has created a resource that researchers can use to study how inherited changes in genes lead to common diseases.  It has established a database and a tissue bank that can be used by many researchers around the world for future studies.
#
# GTEx researchers are studying genes in different tissues obtained from many different people. Thus every donor's generous gift of tissues and medical information to the GTEx project makes possible research that will help improve our understanding of diseases, giving hope that we will find better ways to prevent, diagnose, treat and eventually cure these diseases in the future.
#
# GTEx portal is at https://www.gtexportal.org/home/

# %%
HTML('<iframe src="https://drive.google.com/file/d/0B_ssVVyXv8ZSV2xYRnlHSDJMUTA/preview" width="1000" height="480"></iframe>')
# Out:
# <iframe src="https://drive.google.com/file/d/0B_ssVVyXv8ZSV2xYRnlHSDJMUTA/preview" width="1000" height="480"></iframe>

# %% [markdown]
# Boxplots are a type of graph that is often used to visualize changes in gene expression, as in the GTEx examples below. We will use a python library called [plotnine](https://plotnine.readthedocs.io/en/stable/) to generate boxplots that illustrated changes in gene expression.

# %% [markdown]
# Let's revisit the genes that we examined in the Washu Browser in the last tutorial. Click on the link next to each gene to navigate to the GTEx entry for the gene.
#
# * MYOD1 - muscle https://www.gtexportal.org/home/gene/MYOD1
# * NEUROD1 - neurons https://www.gtexportal.org/home/gene/NEUROD1
# * SPI1 - blood https://www.gtexportal.org/home/gene/SPI1
# * HNF4A - Liver and related https://www.gtexportal.org/home/gene/HNF4A
# * GTF2B - Ubiquitous gene https://www.gtexportal.org/home/gene/GTF2B

# %% [markdown]
# ## How is data from an RNA-Seq experiment processed and stored in a format that can be read into Python? <a name='RNASeqDataFormat' />
#
# We are now going to look at processed and normalized data from the ENCODE portal. 565 RNA-seq samples were collected across multiple tissues and cell types. We begin by looking at the number of sequence reads that align to each gene. The data is stored in a matrix format, with each row corresponding to a gene in the human genome and each column corresponding to an RNA-seq experiment. The values in the matrix are read counts -- specifically the number of reads that align to a given gene. We normalize the data to "counts per million".
# ![alt text](../Images/7-StartingDataFiles.png)
#
# To start analyzing the data from the RNA-Seq experiment one of the first steps is reading the data into a program that can be used for the analysis.
#
# We'll be using Python and will need to first cover some general information about working with datatables.

# %% [markdown]
# # Identify the separator and header in a data table  <a name='IDHeaderSep' />
#
# Two common formats for data tables are comma separated values (**.csv**) files or tab separated values (**.tsv**) files.
#
# In order to read a data table into a program, you often need to know the format of the file. One way to check the format is to look at the files in a text editor. In the figure below, you can see the differences between a file saved in .csv or .tsv format.
#
# Also, when you read a data table into Python (or R) you often need to specify which row of the file has the column labels. This row is referred to as a **header**.
#
# Sometimes a file has extra lines above the header, so you may need to tell the program not to read that row since the extra lines may not have the same number of columns as the rest of the table and they can mess up the formatting.
# ![alt text](../Images/6-Tables-CSV-TSV.png)

# %% [markdown]
# # Load a data table in .csv or .tsv format into Python <a name='LoadTable' />
#
# To read our RNA-Seq data table into Python, we are going to be using the <i>pandas</i> package.
#
# <i>Pandas</i> adds functionality to working with data in Python. You can learn more about <i>pandas</i> at the following [link](http://pandas.pydata.org/). In particular, <i>pandas</i> introduces a variable type called dataframes which are a convient way of working with tables.
#
# After we have imported the <i>pandas</i> package into Python, we can load a .csv or .tsv file with the read_csv or read_table command.
#
# The RNA-Seq data that we will be using is a .tsv file.
#
# Note that the read command also asks for you to specify the row number for the header which in our case is the first line, denoted zero in Python.
#
# Take a look at reading in a file in the example below.

# %%
# load the pandas package and define an abbreviation (or alias) 
import pandas as pd   

# read_table loads a tabular data file into python with tab as the default separator
# read_csv loads a tabular data file into python with comma as the deafault separator
# header gives the number of the row that will be used for column names

#Step 1: Read in the normalized data. 
#rnaseq_data = pd.read_table(
      filepath_or_buffer='../datasets/RNAseq/rnaseq_normalized.tsv', 
      header=0,
      index_col=0)

# %% [markdown]
# Thought questions:
#
# * What would you change the code above to read in a .csv file?
# * How would you need to change the code if your column names were in the third row?

# %% [markdown]
# # How do I know how many genes and cell types I have in my data set (aka. Get the dimensions of a data table in Python)<a name='DataTableDim' />
#
# Once you've read your data set into Python, there are just a couple of commands that you need to look at the size of your dataset.

# %%
#Use the 'head' command to examine the structure of your data matrix. 
rnaseq_data.head()

# %%
#Use the shape command to calculate the dimensions of your data matrix 
#shape[0] gives the number of rows, shape [1] gives the number of columns. 

num_genes=rnaseq_data.shape[0] 
num_samples=rnaseq_data.shape[1] 

#use the print command to print the variables you generated above 
print(num_genes)
print(num_samples)

# %% [markdown]
# Thought questions:
# How many genes were measured in this experiment?
# How many samples were measured?

# %% [markdown]
#  # Load RNA-Seq metadata for the physiological system of a cell type into Python<a name='MetaData' />

# %% [markdown]
# In our example today, we want to compare cell types in different organ systems such as the Nervous system, Musculoskeletal system or Blood.
#
# We have a file that lists the System, Organ and Cell Type for each Sample in the RNA-Seq experiment. This separate file with information about the samples is referred to as **metadata**.
#
# The metadata is stored in a file called: '../datasets/RNAseq/rnaseq_metadata.txt'.
#
# Since the name of the metadata table does not tell you, how can you check if the file is in .csv or .tsv format?
#
# Using what you learned yesterday about reading detatables into Python, write the code to read in the metadata file and to view the top of the file.

# %%
#Step 2: Load the metadata file that provides metadata annotations for each sample 
#(hint: this will be very similar to the code we wrote to load the data table)

# %%
###BEGIN SOLUTION
metadata = pd.read_table(
     filepath_or_buffer='../datasets/RNAseq/rnaseq_metadata.txt', 
     header=0,
     index_col=0)
###END SOLUTION

# %%
num_genes=metadata.shape[0] 
num_samples=metadata.shape[1] 

#use the print command to print the variables you generated above 
print(num_genes)
print(num_samples)
metadata.head()

# %% [markdown]
# ## Slice a data table in Python to select a subset of rows or columns. <a name='Slicing' />
#
# To answer the question <i>"Do cell types from the same organ system have similar gene expression profiles?</i>, we are particularly interested in the column labeled System.
#
# Selecting part of a table is called slicing. It is very common in data analysis work to need to slice a table to select, for example, one column, one row or a set of rows and/or columns.
#
# Using the <i>pandas</i> package, there are a few ways that you can select rows and columns. Below is a table from the pandas [website](https://pandas.pydata.org/pandas-docs/stable/dsintro.html), that summarizes how you can select rows and columns.  For a more complete description and set of examples see this [link](https://pandas.pydata.org/pandas-docs/stable/indexing.html).
#
# <img src="../Images/7-Indexing_Selecting Rows and Columns 2.png" style="width: 60%; height: 60%" align="center"/>
#
# In our example, let's look first at how we would select the System column.

# %%
#Use the 'head' command to examine the structure of your data matrix. 
###BEGIN SOLUTION
metadata.head()
###END SOLUTION

# %%
x=metadata['System']
print(x)

# %%
#Write the code to make a variable x with the Cell Type instead of the System. 
###BEGIN SOLUTION
###END SOLUTION

# %%
#Write the code to make a variable x with the first five rows of metadata 
#(remember to use Python zero-based numbering!). 
###BEGIN SOLUTION
###END SOLUTION

# %% [markdown]
# Notice that the second to last option in the table above indicates that you can specify the location with a Boolean vector. Boolean variables usually are variables that can take on two values, True or False.
#
# Using this syntax, we can write a criteria for the rows that we want to select. For example, if we want to select the rows from only the respiratory system we could specify the condition that System=='Respiratory'

# %%
metadata_subset=metadata.loc[metadata.System=='Respiratory']
print(metadata_subset)

# %% [markdown]
# In the example below, we are going to want to select multiple Systems. To do this, we can use the "|" operator

# %%
metadata_subset=metadata.loc[(metadata.System=='Respiratory') | (metadata.System=='Embryonic')]
print(metadata_subset)

# %% [markdown]
# A more compact way, however, to select a list of cell types is to define a variable for the list of cell types and then use the <i>pandas</i> isin function.

# %%
#define the list of cell types
systems_subset=["Blood","Embryonic","Immune","Respiratory"]

#select the rows in metadata for which the System is one of the 
metadata_subset=metadata.loc[metadata['System'].isin(systems_subset)]

print(metadata_subset)

# %% [markdown]
# Row and column indices can be combined to select subsets of a dataframe. For example, if we'd like to get the System for the sample "ENCSR051GPK.Ganglion_Eminence_derived_primary_cultured_neurospheres.UCSF_Costello". The syntax for row and column selection is combined to:
#
# ![alt_text](../Images/7-GeneSampleSelect.png)

# %%
#First, select the column of interest. Next, use the loc command to select the row name of interest. 
example_gene_expression=metadata["System"].loc["ENCSR051GPK.Ganglion_Eminence_derived_primary_cultured_neurospheres.UCSF_Costello"]
print(example_gene_expression)

# %%
#or, we want to get the system of the 10th sample: 
example_gene_expression=metadata["System"].iloc[9]
print(example_gene_expression)

# %% [markdown]
# ## Make a bar plot from a data table using Python<a name='Barplot' />
#
# Now that we know how to select specific columns from a table, we are going to make a bar plot to look at the number of samples in each of the organ systems.
#
# Specifically, since we have limited computational resources we are going to focus on only four systems today. We want to ensure that we are selecting systems that have a sufficient number of samples.
#
# There are several different packages that can be used to make plots in Python. We will be using the [plotnine](https://plotnine.readthedocs.io/en/stable/api.html) package.

# %%
from plotnine import *

# %%
x=metadata['System']
qplot(x=x,
      geom="bar",
      xlab="System",
      ylab="Samples")+coord_flip()

# %% [markdown]
# ## Transpose a matrix using Python<a name='Transpose' />

# %% [markdown]
# It's not very convenient to have to select metadata characteristics from one dataframe and gene names from another. Merging the sample dataframe and the metadata dataframe into a single dataframe will make slicing and selecting rows and columns more straightforward.
#
# The first step to generate this merged dataframe is to transpose the rows and columns of "rnaseq_data". Transposition is an operation that flips the rows and columns in a matrix, like in the example below.
# ![alt_text](../Images/7-transpose.png)
#
#
# Currently the genes in the rnaseq_dataframe are along the row axis, while sample names are along the column axis. Transposing the matrix will place the genes along the column axis and the sample names along the row axis:
#
#
# ![alt_text](../Images/7-transposeRNA.png)

# %%
transposed_rnaseq_data=rnaseq_data.transpose()
transposed_rnaseq_data.head()
# Out:
#                                                     ENSG00000242268.2  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.675065
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.277090
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.187297
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.104115
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.384825
#
#                                                     ENSG00000167578.12  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            3.176028
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       2.113871
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            2.990098
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      2.860598
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                3.392432
#
#                                                     ENSG00000270112.2  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.100813
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.325754
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.068335
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.067226
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.145993
#
#                                                     ENSG00000078237.4  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           3.750078
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      1.852882
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.030287
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.432092
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.051930
#
#                                                     ENSG00000263642.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.005248
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.007042
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.002427
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.028182
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley              -0.000008
#
#                                                     ENSG00000225275.4  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.008347
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.022288
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.012498
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.015227
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009046
#
#                                                     ENSG00000269416.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.895792
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.654517
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.072950
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.631293
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.286721
#
#                                                     ENSG00000268332.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.071096
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.013041
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.041683
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.242030
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.084697
#
#                                                     ENSG00000060642.6  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.717195
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      1.777113
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.904739
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.311262
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.446061
#
#                                                     ENSG00000231981.3  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.086997
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.168219
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.139392
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.133319
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.137258
#
#                                                           ...          \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...        ...
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                   ...
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...        ...
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                  ...
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley            ...
#
#                                                     ENSG00000089177.13  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            1.864442
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       2.806932
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            2.861718
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      2.268368
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                1.566472
#
#                                                     ENSG00000124214.15  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            3.767551
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       3.914360
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            4.320962
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      3.855545
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                3.608511
#
#                                                     ENSG00000267117.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.012366
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.161303
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.103156
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.191049
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.094820
#
#                                                     ENSG00000148943.7  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           3.007283
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      2.534540
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.166439
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.714726
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.837897
#
#                                                     ENSG00000273233.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.106460
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.102920
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.099807
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.046975
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.012638
#
#                                                     ENSG00000265520.1  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.143332
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.029297
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.040695
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.183519
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.069255
#
#                                                     ENSG00000231119.2  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.102862
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.089795
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.081328
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.162563
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.089867
#
#                                                     ENSG00000105063.14  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            3.135837
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       3.293024
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            3.832852
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      3.613722
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                4.446532
#
#                                                     ENSG00000123685.4  \
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.171673
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.909186
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.175359
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.783756
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               1.255056
#
#                                                     ENSG00000181518.2
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.011186
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.017020
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...          -0.000313
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.003784
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009028
#
# [5 rows x 55667 columns]

# %% [markdown]
# ## Merge two matrices using Python<a name='Merge' />

# %% [markdown]
# Now that the rnaseq_data frame has the sample names along the row axis, same as the metadata tables, the dataframes can be merged together. This will form one matrix with the sample names as rows and the Gene Names, System, Organ and CellType as columns. The merge operation is performed on the sample name column, which is shared across both tables.

# %% [markdown]
# ![alt_text](../Images/7_merging_merge_on_key.png)
# <img src="../Images/7-RNASeq_merged.png" style="width: 80%; height: 80%" align="center"/>

# %%
#merge the metadata and gene expression data into a single data frame 

merged_rnaseq_metadata=pd.merge(transposed_rnaseq_data, metadata, left_index=True,right_index=True)
merged_rnaseq_metadata.head()
# Out:
#                                                     ENSG00000242268.2  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.675065
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.277090
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.187297
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.104115
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.384825
#
#                                                     ENSG00000167578.12  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            3.176028
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       2.113871
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            2.990098
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      2.860598
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                3.392432
#
#                                                     ENSG00000270112.2  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.100813
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.325754
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.068335
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.067226
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.145993
#
#                                                     ENSG00000078237.4  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           3.750078
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      1.852882
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.030287
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.432092
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.051930
#
#                                                     ENSG00000263642.1  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.005248
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.007042
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.002427
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.028182
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley              -0.000008
#
#                                                     ENSG00000225275.4  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.008347
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.022288
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.012498
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.015227
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009046
#
#                                                     ENSG00000269416.1  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.895792
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.654517
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.072950
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.631293
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.286721
#
#                                                     ENSG00000268332.1  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.071096
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.013041
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.041683
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.242030
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.084697
#
#                                                     ENSG00000060642.6  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.717195
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      1.777113
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.904739
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.311262
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.446061
#
#                                                     ENSG00000231981.3  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.086997
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.168219
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.139392
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.133319
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.137258
#
#                                                        ...       \
# Sample                                                 ...
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...     ...
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                ...
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...     ...
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass               ...
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley         ...
#
#                                                     ENSG00000148943.7  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           3.007283
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      2.534540
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.166439
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     2.714726
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.837897
#
#                                                     ENSG00000273233.1  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.106460
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.102920
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.099807
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.046975
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.012638
#
#                                                     ENSG00000265520.1  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.143332
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.029297
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.040695
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    -0.183519
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.069255
#
#                                                     ENSG00000231119.2  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           0.102862
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.089795
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.081328
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.162563
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.089867
#
#                                                     ENSG00000105063.14  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...            3.135837
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                       3.293024
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            3.832852
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                      3.613722
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                4.446532
#
#                                                     ENSG00000123685.4  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...           1.171673
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.909186
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.175359
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.783756
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               1.255056
#
#                                                     ENSG00000181518.2  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          -0.011186
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                      0.017020
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...          -0.000313
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                     0.003784
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009028
#
#                                                              System  \
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...          Nervous
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass             Musculoskeletal
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...        Embryonic
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                    Urinary
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                Blood
#
#                                                           Organ     CellType
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_c...        Brain  Neurosphere
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                  Muscle       Muscle
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...  Trophoblast   ES.derived
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                 Kidney       Kidney
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley            Blood     Leukemia
#
# [5 rows x 55670 columns]

# %% [markdown]
# ###  Using binary indexing to extract elements in a matrix. <a name='BinaryIndex' />

# %% [markdown]
# For the rest of our analysis, we want to focus on 4 Systems and check for differential gene expression among them. In the next block of code we will select these four systems.

# %%
#Pick out the samples in the merged dataframe that contain the samples from the systems of interest 
systems_subset=["Blood","Embryonic","Immune","Respiratory"]
rnaseq_data_subset=merged_rnaseq_metadata.loc[merged_rnaseq_metadata['System'].isin(systems_subset)]
rnaseq_data_subset.head()
# Out:
#                                                     ENSG00000242268.2  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.187297
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.384825
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.805894
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.312230
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.160138
#
#                                                     ENSG00000167578.12  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            2.990098
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                3.392432
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...            2.345439
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...            3.183208
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...            2.133929
#
#                                                     ENSG00000270112.2  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.068335
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.145993
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.033347
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.153861
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.077260
#
#                                                     ENSG00000078237.4  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.030287
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.051930
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           2.783840
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           2.028751
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           2.683576
#
#                                                     ENSG00000263642.1  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.002427
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley              -0.000008
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.004928
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.002950
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.003354
#
#                                                     ENSG00000225275.4  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.012498
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009046
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.014051
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.002064
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.005010
#
#                                                     ENSG00000269416.1  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.072950
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.286721
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...          -0.213324
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.783033
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.668882
#
#                                                     ENSG00000268332.1  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.041683
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.084697
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.093003
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.066531
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.073288
#
#                                                     ENSG00000060642.6  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           1.904739
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.446061
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           2.479022
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           3.088628
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           2.662957
#
#                                                     ENSG00000231981.3  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.139392
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.137258
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.062528
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...          -0.031498
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...          -0.073561
#
#                                                          ...        \
# Sample                                                   ...
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...       ...
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley           ...
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...       ...
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...       ...
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...       ...
#
#                                                     ENSG00000148943.7  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           3.166439
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               2.837897
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           1.990848
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           1.629999
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           2.899638
#
#                                                     ENSG00000273233.1  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.099807
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.012638
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.062083
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.081016
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.038162
#
#                                                     ENSG00000265520.1  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.040695
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.069255
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.084751
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.085211
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.069725
#
#                                                     ENSG00000231119.2  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.081328
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.089867
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.101481
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.120326
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.142189
#
#                                                     ENSG00000105063.14  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...            3.832852
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                4.446532
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...            3.415822
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...            5.430897
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...            3.799500
#
#                                                     ENSG00000123685.4  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...           0.175359
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               1.255056
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           2.394278
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           1.120048
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...           0.782373
#
#                                                     ENSG00000181518.2  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...          -0.000313
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.009028
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.008071
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.001673
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...          -0.013330
#
#                                                          System        Organ  \
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...    Embryonic  Trophoblast
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley            Blood        Blood
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...        Blood        Blood
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...        Blood        Blood
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...  Respiratory         Lung
#
#                                                           CellType
# Sample
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Culture...      ES.derived
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley            Leukemia
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...  Lymphoblastoid
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...             HSC
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Prim...          Smooth
#
# [5 rows x 55670 columns]

# %% [markdown]
# In the code above to select the rows in rnaseq_data for each of the four organ systems we executed the line of code:
#
# ```
# rnaseq_data_subset=merged_df.loc[merged_df['System'].isin(systems_subset)]
# ```
# Let's break down what this line of code is doing.
# First, we find all positions in `merged_df["System"]` that have a specific name. For example:

# %%
name='Blood'
print(name)
merged_rnaseq_metadata['System']==name
# Out:
# Blood
# Sample
# ENCSR051GPK.Ganglion_Eminence_derived_primary_cultured_neurospheres.UCSF_Costello    False
# ENCSR906HEV.Fetal_Muscle_Trunk.UW_Glass                                              False
# ENCSR762CJN.H1_BMP4_Derived_Trophoblast_Cultured_Cells.UCSD_Thompson                 False
# ENCSR321ROU.Fetal_Kidney_Pelvis.UW_Glass                                             False
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley                                        True
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_Graveley                               True
# ENCSR244ISQ.H9_Derived_Neuronal_Progenitor_Cultured_Cells.CSHL_Gingeras              False
# ENCSR446RKD.Fetal_Intestine_Small.UW_Glass                                           False
# ENCSR396GIH.Sigmoid_Colon.Stanford_Snyder                                            False
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CSHL_Gingeras                            True
# ENCSR184FRM.Mammary_Gland_Luminal_Epithelial_Primary_Cells.UCSF_Costello             False
# ENCSR000CUE.Articular_Chondrocyte_of_Knee_Joint.CSHL_Gingeras                        False
# ENCSR000AAN.Pulmonary_Artery_Smooth_Muscle_Primary_Cells.CSHL_Gingeras               False
# ENCSR951NPS.Fetal_Stomach.UW_Glass                                                   False
# ENCSR652AWW.Fetal_Muscle_Back.UW_Glass                                               False
# ENCSR160UAZ.Fetal_Kidney_Pelvis.UW_Glass                                             False
# ENCSR443JOD.Fetal_Brain_Female.UCSF_Costello                                         False
# ENCSR463JBR.Primary_T_CD4._cells_from_peripheral_blood.FHCRC_Heimfeld                 True
# ENCSR400DJE.Fetal_Kidney_Cortex.UW_Glass                                             False
# ENCSR265NZF.Fetal_Spleen.UW_Glass                                                    False
# ENCSR069CMT.Fetal_Thymus.UW_Glass                                                    False
# ENCSR000CUI.Muscle_Satellite_Cultured_Cells.CSHL_Gingeras                            False
# ENCSR884EVS.Fetal_Kidney_Cortex.UW_Glass                                             False
# ENCSR675YAS.Right_Atrium.Stanford_Snyder                                             False
# ENCSR499NEL.Fetal_Lung.UW_Glass                                                      False
# ENCSR593AMV.hESC_Derived_CD56._Ectoderm_Cultured_Cells.Harvard                       False
# ENCSR663WGC.H1_Derived_Mesenchymal_Stem_Cells.UCSD_Thomson                           False
# ENCSR361DRG.Fetal_Skin_Fibroblast_Abdomen.UW_Glass                                   False
# ENCSR367QHR.Fetal_Thymus.UW_Glass                                                    False
# ENCSR825GWD.Sigmoid_Colon.Stanford_Snyder                                            False
#                                                                                      ...
# ENCSR000AFK.Fetal_Thyroid.CSHL_Gingeras                                              False
# ENCSR449GLL.Primary_B_cells_from_peripheral_blood.FHCRC_Heimfeld                      True
# ENCSR727VTD.Fetal_Ovary.UW_Glass                                                     False
# ENCSR721HDG.Gastric.Stanford_Snyder                                                  False
# ENCSR256YHI.Cortex_derived_primary_cultured_neurospheres.UCSF_Costello               False
# ENCSR000AHH.Fetal_Heart.CSHL_Gingeras                                                False
# ENCSR410DUZ.Fetal_Kidney_Pelvis.UW_Glass                                             False
# ENCSR995ORR.Fetal_Muscle_Back.UW_Glass                                               False
# ENCSR000EYP.H1_Cells.Caltech_Wold                                                    False
# ENCSR000CUC.Primary_monocytes_from_peripheral_blood.CSHL_Gingeras                     True
# ENCSR118TVR.Kidney_Proximal_Tube_Epithelial_Primary_Cells.CSHL_Gingeras              False
# ENCSR328PVI.Fetal_Kidney_Cortex.UW_Glass                                             False
# ENCSR568YRP.SJCRH30_Rhabdomyosarcoma_Cell_Line.CSHL_Gingeras                         False
# ENCSR681ALA.Fetal_Skin_Fibroblast_Abdomen.UW_Glass                                   False
# ENCSR899NLW.Fetal_Spinal_Cord.UW_Glass                                               False
# ENCSR000AFN.Uterus.CSHL_Gingeras                                                     False
# ENCSR254JJM.Daoy_Desmoplastic_Cerebellar_Medulloblastoma_Cell_Line.CSHL_Gingeras     False
# ENCSR204XBB.Fetal_Kidney_Pelvis.UW_Glass                                             False
# ENCSR096USV.Fetal_Muscle_Leg.UW_Glass                                                False
# ENCSR136WGP.SK.N.DZ_Neuroblastoma_Cell_Line.CSHL_Gingeras                            False
# ENCSR271DJJ.Pancreatic_Islets.UCSF_Costello                                          False
# ENCSR000AED.GM12878_Lymphoblastoid_Cells.CSHL_Gingeras                                True
# ENCSR433GXV.hESC_Derived_CD56._Mesoderm_Cultured_Cells.Harvard                       False
# ENCSR535VTR.HT1080_Fibrosarcoma_Cell_Line.CSHL_Gingeras                              False
# ENCSR000AEV.Bladder.CSHL_Gingeras                                                    False
# ENCSR314LXG.Karpas.422_B_Cell_Non.Hodgkin_Lymphoma_Cell_Line.CSHL_Gingeras            True
# ENCSR642GSA.Primary_T_CD8._naive_cells_from_peripheral_blood.UCSF_Costello            True
# ENCSR880EGO.SJSA1_Osteosarcoma_Cell_Line.CSHL_Gingeras                               False
# ENCSR000AAT.Umbilical_Artery_Epithelial_Primary_Cells.CSHL_Gingeras                  False
# ENCSR000EYQ.HeLa.S3_Cervical_Carcinoma_Cell_Line.Caltech_Wold                        False
# Name: System, Length: 410, dtype: bool

# %% [markdown]
# Note that `merged_rnaseq_metadata['System']==name` returns a value of "True" or "False" at each position in the` merged_rnaseq_metadata['System']` array. This is referred to as binary indexing.
#
# Next, we identify the rows with a value of "True", and select them from `merged_df.loc`.
# This is done with the command:

# %%
merged_rnaseq_metadata.loc[merged_rnaseq_metadata["System"]==name]
# Out:
#                                                     ENSG00000242268.2  \
# Sample
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley               0.384825
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...           0.805894
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...           0.312230
# ENCSR463JBR.Primary_T_CD4._cells_from_periphera...           0.320575
# ENCSR357XTU.Primary_Natural_Killer_cells_from_p
# ENCSR000EYN.GM12878_Lymphoblastoid_Cells.Caltec...           0.010035   Blood
# ENCSR000AEQ.K562_Leukemia_Cells.Caltech_Wold                 0.014251   Blood
# ENCSR239EBA.Primary_T_helper_naive_cells_from_p...           0.001352   Blood
# ENCSR763CQW.Primary_T_cells_from_peripheral_blo...          -0.001347   Blood
# ENCSR000CUT.Primary_mononuclear_cells_from_peri...          -0.002330   Blood
# ENCSRMAR039.Primary_T_helper_naive_cells_from_p...           0.003359   Blood
# ENCSR000CTV.Primary_CD20._B_cells_from_peripher...           0.001968   Blood
# ENCSRMAR042.Primary_T_helper_17_cells_PMA.I_sti...           0.015112   Blood
# ENCSR000AEO.K562_Leukemia_Cells.UConn_Graveley               0.008925   Blood
# ENCSR000CWK.GM12891_Lymphoblastoid_Cells.Caltec...           0.015593   Blood
# ENCSR861QKF.Primary_T_CD8._cells_from_periphera...           0.011204   Blood
# ENCSR313TJR.Primary_mononuclear_cells_from_peri...           0.008891   Blood
# ENCSR489KLG.Primary_T_helper_2_memory_cells_fro...           0.000948   Blood
# ENCSR000AEE.GM12878_Lymphoblastoid_Cells.UConn_...           0.006162   Blood
# ENCSR905LVO.Primary_monocytes_from_peripheral_b...           0.006679   Blood
# ENCSR000EYO.K562_Leukemia_Cells.Caltech_Wold                 0.010939   Blood
# ENCSR000BXX.Jurkat_Lymphoblastoid_Cell_Line.HAI...           0.015679   Blood
# ENCSR000CPH.K562_Leukemia_Cells.CSHL_Gingeras                0.002596   Blood
# ENCSRMAR040.Primary_T_helper_1_memory_cells_fro...           0.004904   Blood
# ENCSR001HHK.Oci.Ly.7_B_Cell_Non.Hodgkin_Lymphom...          -0.017809   Blood
# ENCSR000AEM.K562_Leukemia_Cells.CSHL_Gingeras                0.002327   Blood
# ENCSRMAR044.Primary_T_regulatory_cells_from_per...           0.003512   Blood
# ENCSR545MEZ.Primary_T_CD4._cells_from_periphera...           0.007069   Blood
# ENCSR000COQ.GM12878_Lymphoblastoid_Cells.CSHL_G...          -0.002632   Blood
# ENCSR000AEL.K562_Leukemia_Cells.CSHL_Gingeras               -0.002098   Blood
# ENCSR000CUC.Monocytes.CD14._RO01746_Primary_Cel...           0.006289   Blood
# ENCSR000CWL.GM12892_Lymphoblastoid_Cells.Caltec...           0.000520   Blood
# ENCSRMAR045.Primary_T_cells_effector_memory_enr...           0.006752   Blood
# ENCSR449GLL.Primary_B_cells_from_peripheral_blo...          -0.000024   Blood
# ENCSR000CUC.Primary_monocytes_from_peripheral_b...           0.006168   Blood
# ENCSR000AED.GM12878_Lymphoblastoid_Cells.CSHL_G...           0.000062   Blood
# ENCSR314LXG.Karpas.422_B_Cell_Non.Hodgkin_Lymph...          -0.014062   Blood
# ENCSR642GSA.Primary_T_CD8._naive_cells_from_per...          -0.000958   Blood
#
#                                                     Organ        CellType
# Sample
# ENCSR109IQO.K562_Leukemia_Cells.UConn_Graveley      Blood        Leukemia
# ENCSR000AEF.GM12878_Lymphoblastoid_Cells.UConn_...  Blood  Lymphoblastoid
# ENCSR000CUA.Primary_hematopoietic_stem_cells.CS...  Blood             HSC
# ENCSR463JBR.Primary_T_CD4._cells_from_periphera...  Blood          T.cell
# ENCSR357XTU.Primary_Natural_Killer_cells_from_p...  Blood          B.cell
# ENCSR944FLL.Primary_T_CD8._cells_from_periphera...  Blood          T.cell
# ENCSR409JSP.Primary_mononuclear_cells_from_peri...  Blood          T.cell
# ENCSR000AEN.K562_Leukemia_Cells.UConn_Graveley      Blood        Leukemia
# ENCSR000AEC.GM12878_Lymphoblastoid_Cells.CSHL_G...  Blood  Lymphoblastoid
# ENCSR830HIN.Primary_hematopoietic_stem_cells.FH...  Blood             HSC
# ENCSR001ODS.Primary_mononuclear_cells_from_peri...  Blood          T.cell
# ENCSRMAR043.Primary_T_helper_cells_from_periphe...  Blood          T.cell
# ENCSRMAR041.Primary_T_helper_cells_PMA.I_stimul...  Blood          T.cell
# ENCSR000EYN.GM12878_Lymphoblastoid_Cells.Caltec...  Blood  Lymphoblastoid
# ENCSR000AEQ.K562_Leukemia_Cells.Caltech_Wold        Blood        Leukemia
# ENCSR239EBA.Primary_T_helper_naive_cells_from_p...  Blood          T.cell
# ENCSR763CQW.Primary_T_cells_from_peripheral_blo...  Blood          T.cell
# ENCSR000CUT.Primary_mononuclear_cells_from_peri...  Blood          T.cell
# ENCSRMAR039.Primary_T_helper_naive_cells_from_p...  Blood          T.cell
# ENCSR000CTV.Primary_CD20._B_cells_from_peripher...  Blood          B.cell
# ENCSRMAR042.Primary_T_helper_17_cells_PMA.I_sti...  Blood          T.cell
# ENCSR000AEO.K562_Leukemia_Cells.UConn_Graveley      Blood        Leukemia
# ENCSR000CWK.GM12891_Lymphoblastoid_Cells.Caltec...  Blood  Lymphoblastoid
# ENCSR861QKF.Primary_T_CD8._cells_from_periphera...  Blood          T.cell
# ENCSR313TJR.Primary_mononuclear_cells_from_peri...  Blood          T.cell
# ENCSR489KLG.Primary_T_helper_2_memory_cells_fro...  Blood          T.cell
# ENCSR000AEE.GM12878_Lymphoblastoid_Cells.UConn_...  Blood  Lymphoblastoid
# ENCSR905LVO.Primary_monocytes_from_peripheral_b...  Blood          B.cell
# ENCSR000EYO.K562_Leukemia_Cells.Caltech_Wold        Blood        Leukemia
# ENCSR000BXX.Jurkat_Lymphoblastoid_Cell_Line.HAI...  Blood  Lymphoblastoid
# ENCSR000CPH.K562_Leukemia_Cells.CSHL_Gingeras       Blood        Leukemia
# ENCSRMAR040.Primary_T_helper_1_memory_cells_fro...  Blood          T.cell
# ENCSR001HHK.Oci.Ly.7_B_Cell_Non.Hodgkin_Lymphom...  Blood        Lymphoma
# ENCSR000AEM.K562_Leukemia_Cells.CSHL_Gingeras       Blood        Leukemia
# ENCSRMAR044.Primary_T_regulatory_cells_from_per...  Blood          T.cell
# ENCSR545MEZ.Primary_T_CD4._cells_from_periphera...  Blood          T.cell
# ENCSR000COQ.GM12878_Lymphoblastoid_Cells.CSHL_G...  Blood  Lymphoblastoid
# ENCSR000AEL.K562_Leukemia_Cells.CSHL_Gingeras       Blood        Leukemia
# ENCSR000CUC.Monocytes.CD14._RO01746_Primary_Cel...  Blood          B.cell
# ENCSR000CWL.GM12892_Lymphoblastoid_Cells.Caltec...  Blood  Lymphoblastoid
# ENCSRMAR045.Primary_T_cells_effector_memory_enr...  Blood          T.cell
# ENCSR449GLL.Primary_B_cells_from_peripheral_blo...  Blood          B.cell
# ENCSR000CUC.Primary_monocytes_from_peripheral_b...  Blood          B.cell
# ENCSR000AED.GM12878_Lymphoblastoid_Cells.CSHL_G...  Blood  Lymphoblastoid
# ENCSR314LXG.Karpas.422_B_Cell_Non.Hodgkin_Lymph...  Blood        Lymphoma
# ENCSR642GSA.Primary_T_CD8._naive_cells_from_per...  Blood          T.cell
#
# [46 rows x 55670 columns]

# %% [markdown]
# This has allowed us to create positional indices from the binary True/False indices.

# %%
#Lets now check the row & column numbers in rnaseq_data_subset 
print(rnaseq_data_subset.shape[0])#prints number of rows -- this is the gene axis 
print(rnaseq_data_subset.shape[1])#prints number of columns
# Out:
# 116
# 55670

# %% [markdown]
# Earlier the size of the matrix was:
#
# 55667 <br>
# 410
#
# Thought question: What is the difference between the rnaseq_data_subset matrix that we just made and the original rnaseq_data matrix?

# %%
#Now, we create a barplot with just our 4 organ systems of interest 
#(ggplot(rnaseq_data_subset, aes(x='System'))
# + geom_bar()
# +coord_flip()
#)
x=rnaseq_data_subset['System']
qplot(x=x,
      geom="bar",
      xlab="System",
      ylab="Samples")

# %% [markdown]
# As a final step in preparing the dataframe, we are only interested in genes that are differentially expressed across samples, so we can exclude genes that have 0 TPM
# in all samples -- these are not of interest. We can use the sum command to find such genes

# %%
#Selects rows in the datafile subset for which the sum of the columns is not = to zero. 
rnaseq_data_subset=rnaseq_data_subset[rnaseq_data_subset.sum(axis=1)!=0]

# %%
#Lets now check the row & column numbers in rnaseq_data_subset 
print(rnaseq_data_subset.shape[0])#prints number of rows -- this is the gene axis 
print(rnaseq_data_subset.shape[1])#prints number of columns
# Out:
# 116
# 55670

# %% [markdown]
# Thought question: How many genes had TPM of 0 in all samples?
